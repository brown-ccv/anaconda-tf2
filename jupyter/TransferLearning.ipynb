# %%
# Define which data to load

path = 'D:\\work\\48h_output\\'
subfolder = 'max\\'
channel = 'ch3\\' # eg, "ch3\\"
ending = '.png'
output = '.\\'
f = open(output + "info2.txt", "a")
f.write(path + subfolder + channel+ "*" + ending)
f.close()

# %%
#Parameters 

IMAGE_SIZE = 270 #540 max
CHANNELS = 3 #Note we always set Channels to 3 for transfer learning even if it has only 1 channel
IMG_SHAPE = (IMAGE_SIZE,IMAGE_SIZE, CHANNELS)
BATCH_SIZE = 8
VALIDATION_SPLIT = 0.3

# %%
# Import Data from the csv

import csv
import numpy as np
import tensorflow as tf
import sklearn
from sklearn.model_selection import train_test_split

labels = []
images = []

#read csv file
with open(path + 'descriptor.txt') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        #skip CNT for now
        if row[1] != 'CNT':
            images.append(path + subfolder + channel+ row[0] + ending) 
            labels.append(row[1])

# %%
#split in train and test data

train_size = 0.9; 
train_filenames, test_filenames, train_labels, test_labels = train_test_split(images, labels,train_size = train_size,random_state=42)

# %%
#create panda dataFrame for traindata
import pandas as pd
d_train= {'filename': train_filenames, 'class': train_labels}
df_train = pd.DataFrame(data=d_train)

#print info
print(df_train.groupby(['class']).size())
print(df_train)
# Out:
# class
# CB    72
# UT    66
# dtype: int64
#                                filename class
# 0    D:\work\48h_output\max\ch3\187.png    UT
# 1    D:\work\48h_output\max\ch3\012.png    CB
# 2    D:\work\48h_output\max\ch3\009.png    CB
# 3    D:\work\48h_output\max\ch3\182.png    UT
# 4    D:\work\48h_output\max\ch3\029.png    CB
# ..                                  ...   ...
# 133  D:\work\48h_output\max\ch3\071.png    CB
# 134  D:\work\48h_output\max\ch3\174.png    UT
# 135  D:\work\48h_output\max\ch3\014.png    CB
# 136  D:\work\48h_output\max\ch3\160.png    UT
# 137  D:\work\48h_output\max\ch3\170.png    UT
#
# [138 rows x 2 columns]

# %%
import pandas as pd

#create panda dataFrame for testdata
d_test = {'filename': test_filenames, 'class': test_labels}
df_test = pd.DataFrame(data=d_test)
df_test.groupby(['class']).size()

#print info
print(df_test.groupby(['class']).size())
print(df_test)
# Out:
# class
# CB    7
# UT    9
# dtype: int64
#                               filename class
# 0   D:\work\48h_output\max\ch3\015.png    CB
# 1   D:\work\48h_output\max\ch3\162.png    UT
# 2   D:\work\48h_output\max\ch3\220.png    UT
# 3   D:\work\48h_output\max\ch3\173.png    UT
# 4   D:\work\48h_output\max\ch3\177.png    UT
# 5   D:\work\48h_output\max\ch3\065.png    CB
# 6   D:\work\48h_output\max\ch3\018.png    CB
# 7   D:\work\48h_output\max\ch3\045.png    CB
# 8   D:\work\48h_output\max\ch3\036.png    CB
# 9   D:\work\48h_output\max\ch3\055.png    CB
# 10  D:\work\48h_output\max\ch3\153.png    UT
# 11  D:\work\48h_output\max\ch3\210.png    UT
# 12  D:\work\48h_output\max\ch3\019.png    CB
# 13  D:\work\48h_output\max\ch3\215.png    UT
# 14  D:\work\48h_output\max\ch3\154.png    UT
# 15  D:\work\48h_output\max\ch3\161.png    UT

# %%
from tensorflow.python.keras import backend as K 

K.clear_session()

# %%
#setup datagenerators

from tensorflow.keras.preprocessing.image import ImageDataGenerator
import random

#create Image generator
datagen = ImageDataGenerator(
        rescale=1./255,  # set values to 0-1
        rotation_range=180, # rotation does not matter
        width_shift_range=0.2, # 20 % border
        height_shift_range=0.2,
        horizontal_flip=True, # flip does not matter
        vertical_flip=True, # flip does not matter
        fill_mode="nearest", 
        validation_split=VALIDATION_SPLIT) 


#create random seed
seed = random.seed()


#Note. not sure if these have to be reshuffled during iterations
#create generator for training data
train_generator = datagen.flow_from_dataframe(
        dataframe=df_train,
        x_col="filename",
        y_col="class",
        target_size=(IMAGE_SIZE, IMAGE_SIZE),
        batch_size=BATCH_SIZE,
        class_mode='binary',
        subset='training',
        seed = seed,
        shuffle=True,
        color_mode = 'grayscale' if CHANNELS == 1 else 'rgb' )

#create generator for validation data
validation_generator = datagen.flow_from_dataframe(
        dataframe=df_train,
        x_col="filename",
        y_col="class",
        target_size=(IMAGE_SIZE, IMAGE_SIZE),
        batch_size=BATCH_SIZE,
        class_mode='binary',
        subset='validation',
        seed = seed,
        shuffle=True,
        color_mode = 'grayscale' if CHANNELS == 1 else 'rgb' )

print(train_generator.class_indices)
print(validation_generator.class_indices)
# Out:
# Found 97 validated image filenames belonging to 2 classes.
# Found 41 validated image filenames belonging to 2 classes.
# {'CB': 0, 'UT': 1}
# {'CB': 0, 'UT': 1}

# %%
from matplotlib import pyplot as plt
count = 0 
for X_batch, y_batch in train_generator:
    
    if count > 50 : # stop after 50 images
        break
        
    # create a grid of 3x3 images
    for i in range(0, len(X_batch)):
        count+=1
        label = list(train_generator.class_indices.keys())[list(train_generator.class_indices.values()).index(y_batch[i])]

        fig = plt.figure(figsize = (10,10))
        sp = fig.add_subplot(111)
        sp.set_title(str(count) + " - " + label)
        if CHANNELS == 1:
            sp.imshow(X_batch[i].reshape(IMAGE_SIZE,IMAGE_SIZE), interpolation='none',  cmap='gray')
        else:
            sp.imshow(X_batch[i].reshape(IMG_SHAPE), interpolation='none')

        # show the plot
        plt.show()

# %%
#create network
import tensorflow as tf

# Pre-trained model with MobileNetV2
base_model = tf.keras.applications.MobileNetV2(
    input_shape=IMG_SHAPE,
    include_top=False,
    weights='imagenet'
)

# Freeze the pre-trained model weights
base_model.trainable = False
# Trainable classification head
maxpool_layer = tf.keras.layers.GlobalMaxPooling2D()
prediction_layer = tf.keras.layers.Dense(1, activation='sigmoid')
learning_rate = 0.0001
# Layer classification head with feature detector
model = tf.keras.Sequential([
    base_model,
    maxpool_layer,
    prediction_layer
])

# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(lr=learning_rate), 
              loss='binary_crossentropy',
              metrics=['accuracy']
)
         
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenetv2_1.00_224 (Model) (None, 9, 9, 1280)        2257984
# _________________________________________________________________
# global_max_pooling2d_3 (Glob (None, 1280)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 1281
# =================================================================
# Total params: 2,259,265
# Trainable params: 1,281
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
#Train network
from PIL import Image

num_epochs = 100
steps_per_epoch = train_generator.n//train_generator.batch_size
val_steps = validation_generator.n//validation_generator.batch_size

history = model.fit(
        train_generator,
        steps_per_epoch=steps_per_epoch,
        epochs=num_epochs,
        validation_data=validation_generator,
        validation_steps=val_steps)
# Out:
# Train for 12 steps, validate for 5 steps
# Epoch 1/100
# 12/12 [==============================] - 6s 474ms/step - loss: 2.9770 - accuracy: 0.4831 - val_loss: 2.8671 - val_accuracy: 0.4250
# Epoch 2/100
# 12/12 [==============================] - 2s 170ms/step - loss: 0.9988 - accuracy: 0.5843 - val_loss: 2.0716 - val_accuracy: 0.4000
# Epoch 3/100
# 12/12 [==============================] - 2s 171ms/step - loss: 1.2666 - accuracy: 0.5506 - val_loss: 2.2713 - val_accuracy: 0.4250
# Epoch 4/100
# 12/12 [==============================] - 2s 172ms/step - loss: 1.0948 - accuracy: 0.5393 - val_loss: 2.2259 - val_accuracy: 0.4250
# Epoch 5/100
# 12/12 [==============================] - 2s 171ms/step - loss: 1.0862 - accuracy: 0.5169 - val_loss: 2.4892 - val_accuracy: 0.4500
# Epoch 6/100
# 12/12 [==============================] - 2s 171ms/step - loss: 1.1010 - accuracy: 0.4944 - val_loss: 2.4385 - val_accuracy: 0.4500
# Epoch 7/100
# 12/12 [==============================] - 2s 169ms/step - loss: 1.1996 - accuracy: 0.4831 - val_loss: 2.2371 - val_accuracy: 0.4500
# Epoch 8/100
# 12/12 [==============================] - 2s 170ms/step - loss: 1.1785 - accuracy: 0.5393 - val_loss: 1.8297 - val_accuracy: 0.4500
# Epoch 9/100
# 12/12 [==============================] - 2s 172ms/step - loss: 1.2744 - accuracy: 0.4944 - val_loss: 1.8483 - val_accuracy: 0.4500
# Epoch 10/100
# 12/12 [==============================] - 2s 171ms/step - loss: 1.4941 - accuracy: 0.4494 - val_loss: 2.5020 - val_accuracy: 0.4500
# Epoch 11/100
# 12/12 [==============================] - 2s 173ms/step - loss: 1.2280 - accuracy: 0.5506 - val_loss: 2.3888 - val_accuracy: 0.4500
# Epoch 12/100
# 12/12 [==============================] - 2s 175ms/step - loss: 1.1541 - accuracy: 0.5104 - val_loss: 2.2498 - val_accuracy: 0.4500
# Epoch 13/100
# 12/12 [==============================] - 2s 173ms/step - loss: 0.9193 - accuracy: 0.5730 - val_loss: 2.3649 - val_accuracy: 0.4500
# Epoch 14/100
# 12/12 [==============================] - 2s 173ms/step - loss: 1.0073 - accuracy: 0.5618 - val_loss: 2.1728 - val_accuracy: 0.4500
# Epoch 15/100
# 12/12 [==============================] - 2s 173ms/step - loss: 1.1574 - accuracy: 0.5506 - val_loss: 2.0171 - val_accuracy: 0.4500
# Epoch 16/100
# 12/12 [==============================] - 2s 170ms/step - loss: 1.0530 - accuracy: 0.5393 - val_loss: 2.2715 - val_accuracy: 0.4500
# Epoch 17/100
# 12/12 [==============================] - 2s 170ms/step - loss: 1.0408 - accuracy: 0.4831 - val_loss: 2.1478 - val_accuracy: 0.4500
# Epoch 18/100
# 12/12 [==============================] - 2s 171ms/step - loss: 1.0325 - accuracy: 0.4719 - val_loss: 2.2516 - val_accuracy: 0.4500
# Epoch 19/100
# 12/12 [==============================] - 2s 172ms/step - loss: 1.3033 - accuracy: 0.4831 - val_loss: 2.3882 - val_accuracy: 0.4000
# Epoch 20/100
# 12/12 [==============================] - 2s 171ms/step - loss: 1.1241 - accuracy: 0.4719 - val_loss: 1.9334 - val_accuracy: 0.4500
# Epoch 21/100
# 12/12 [==============================] - 2s 170ms/step - loss: 1.0350 - accuracy: 0.5955 - val_loss: 2.4508 - val_accuracy: 0.4750
# Epoch 22/100
# 12/12 [==============================] - 2s 170ms/step - loss: 1.2413 - accuracy: 0.5056 - val_loss: 2.0431 - val_accuracy: 0.4250
# Epoch 23/100
# 12/12 [==============================] - 2s 170ms/step - loss: 1.2179 - accuracy: 0.5056 - val_loss: 2.1597 - val_accuracy: 0.4500
# Epoch 24/100
# 12/12 [==============================] - 2s 171ms/step - loss: 1.1773 - accuracy: 0.5506 - val_loss: 2.4419 - val_accuracy: 0.4500
# Epoch 25/100
# 12/12 [==============================] - 2s 172ms/step - loss: 1.1087 - accuracy: 0.5506 - val_loss: 2.4929 - val_accuracy: 0.4500
# Epoch 26/100
# 12/12 [==============================] - 2s 171ms/step - loss: 1.1025 - accuracy: 0.5281 - val_loss: 2.1496 - val_accuracy: 0.4500
# Epoch 27/100
# 12/12 [==============================] - 2s 172ms/step - loss: 1.1110 - accuracy: 0.5393 - val_loss: 2.1059 - val_accuracy: 0.4500
# Epoch 28/100
# 12/12 [==============================] - 2s 170ms/step - loss: 1.2301 - accuracy: 0.4494 - val_loss: 2.2672 - val_accuracy: 0.4250
# Epoch 29/100
# 12/12 [==============================] - 2s 171ms/step - loss: 1.0683 - accuracy: 0.5169 - val_loss: 2.1759 - val_accuracy: 0.4250
# Epoch 30/100
# 12/12 [==============================] - 2s 170ms/step - loss: 0.8852 - accuracy: 0.5730 - val_loss: 2.1295 - val_accuracy: 0.4500
# Epoch 31/100
# 12/12 [==============================] - 2s 168ms/step - loss: 1.1066 - accuracy: 0.5506 - val_loss: 2.1813 - val_accuracy: 0.4250
# Epoch 32/100
# 12/12 [==============================] - 2s 172ms/step - loss: 1.1526 - accuracy: 0.5056 - val_loss: 1.9781 - val_accuracy: 0.4500
# Epoch 33/100
# 12/12 [==============================] - 2s 170ms/step - loss: 1.0132 - accuracy: 0.5955 - val_loss: 2.0586 - val_accuracy: 0.4250
# Epoch 34/100
# 12/12 [==============================] - 2s 171ms/step - loss: 0.9372 - accuracy: 0.6067 - val_loss: 2.0626 - val_accuracy: 0.4500
# Epoch 35/100
# 12/12 [==============================] - 2s 171ms/step - loss: 0.9676 - accuracy: 0.5618 - val_loss: 2.0409 - val_accuracy: 0.4250
# Epoch 36/100
# 12/12 [==============================] - 2s 173ms/step - loss: 1.1023 - accuracy: 0.5393 - val_loss: 2.1373 - val_accuracy: 0.4000
# Epoch 37/100
# 12/12 [==============================] - 2s 172ms/step - loss: 1.0807 - accuracy: 0.5169 - val_loss: 2.3676 - val_accuracy: 0.4500
# Epoch 38/100
# 12/12 [==============================] - 2s 175ms/step - loss: 1.1467 - accuracy: 0.5281 - val_loss: 2.0089 - val_accuracy: 0.4250
# Epoch 39/100
# 12/12 [==============================] - 2s 174ms/step - loss: 1.2249 - accuracy: 0.4792 - val_loss: 2.0516 - val_accuracy: 0.4750
# Epoch 40/100
# 12/12 [==============================] - 2s 172ms/step - loss: 0.8859 - accuracy: 0.5618 - val_loss: 2.1198 - val_accuracy: 0.4500
# Epoch 41/100
# 12/12 [==============================] - 2s 170ms/step - loss: 1.1569 - accuracy: 0.4831 - val_loss: 1.9590 - val_accuracy: 0.4500
# Epoch 42/100
# 12/12 [==============================] - 2s 172ms/step - loss: 1.0289 - accuracy: 0.5281 - val_loss: 2.1025 - val_accuracy: 0.4500
# Epoch 43/100
# 12/12 [==============================] - 2s 174ms/step - loss: 1.0576 - accuracy: 0.5281 - val_loss: 2.0315 - val_accuracy: 0.4500
# Epoch 44/100
# 12/12 [==============================] - 2s 172ms/step - loss: 0.9049 - accuracy: 0.5506 - val_loss: 2.1331 - val_accuracy: 0.4500
# Epoch 45/100
# 12/12 [==============================] - 2s 172ms/step - loss: 1.1449 - accuracy: 0.4831 - val_loss: 2.0570 - val_accuracy: 0.4500
# Epoch 46/100
# 12/12 [==============================] - 2s 174ms/step - loss: 1.2168 - accuracy: 0.4382 - val_loss: 1.7475 - val_accuracy: 0.4500
# Epoch 47/100
# 12/12 [==============================] - 2s 177ms/step - loss: 1.0136 - accuracy: 0.4944 - val_loss: 1.9889 - val_accuracy: 0.4250
# Epoch 48/100
# 12/12 [==============================] - 2s 172ms/step - loss: 0.8318 - accuracy: 0.6742 - val_loss: 1.6776 - val_accuracy: 0.5000
# Epoch 49/100
# 12/12 [==============================] - 2s 176ms/step - loss: 1.1136 - accuracy: 0.4719 - val_loss: 2.2833 - val_accuracy: 0.4250
# Epoch 50/100
# 12/12 [==============================] - 2s 173ms/step - loss: 1.0695 - accuracy: 0.5169 - val_loss: 1.8288 - val_accuracy: 0.4250
# Epoch 51/100
# 12/12 [==============================] - 2s 174ms/step - loss: 1.0246 - accuracy: 0.5618 - val_loss: 2.2122 - val_accuracy: 0.4500
# Epoch 52/100
# 12/12 [==============================] - 2s 173ms/step - loss: 1.0344 - accuracy: 0.4896 - val_loss: 1.9614 - val_accuracy: 0.4500
# Epoch 53/100
# 12/12 [==============================] - 2s 169ms/step - loss: 0.9880 - accuracy: 0.5729 - val_loss: 2.2515 - val_accuracy: 0.4500
# Epoch 54/100
# 12/12 [==============================] - 2s 172ms/step - loss: 0.9901 - accuracy: 0.5843 - val_loss: 2.1751 - val_accuracy: 0.4500
# Epoch 55/100
# 12/12 [==============================] - 2s 171ms/step - loss: 0.9955 - accuracy: 0.5169 - val_loss: 2.1948 - val_accuracy: 0.4500
# Epoch 56/100
# 12/12 [==============================] - 2s 173ms/step - loss: 1.1145 - accuracy: 0.4719 - val_loss: 2.1123 - val_accuracy: 0.4500
# Epoch 57/100
# 12/12 [==============================] - 2s 178ms/step - loss: 1.0161 - accuracy: 0.5506 - val_loss: 2.1468 - val_accuracy: 0.4500
# Epoch 58/100
# 12/12 [==============================] - 2s 171ms/step - loss: 0.9044 - accuracy: 0.5506 - val_loss: 1.9292 - val_accuracy: 0.4500
# Epoch 59/100
# 12/12 [==============================] - 2s 169ms/step - loss: 1.1114 - accuracy: 0.5281 - val_loss: 2.1620 - val_accuracy: 0.4500
# Epoch 60/100
# 12/12 [==============================] - 2s 173ms/step - loss: 1.0863 - accuracy: 0.5506 - val_loss: 2.0199 - val_accuracy: 0.4750
# Epoch 61/100
# 12/12 [==============================] - 2s 172ms/step - loss: 0.8142 - accuracy: 0.6854 - val_loss: 2.2485 - val_accuracy: 0.4750
# Epoch 62/100
# 12/12 [==============================] - 2s 171ms/step - loss: 0.7507 - accuracy: 0.7079 - val_loss: 2.2320 - val_accuracy: 0.4500
# Epoch 63/100
# 12/12 [==============================] - 2s 169ms/step - loss: 1.2446 - accuracy: 0.5056 - val_loss: 1.8266 - val_accuracy: 0.3750
# Epoch 64/100
# 12/12 [==============================] - 2s 172ms/step - loss: 1.1050 - accuracy: 0.5506 - val_loss: 1.9749 - val_accuracy: 0.4500
# Epoch 65/100
# 12/12 [==============================] - 2s 171ms/step - loss: 1.0521 - accuracy: 0.5281 - val_loss: 1.7666 - val_accuracy: 0.4500
# Epoch 66/100
# 12/12 [==============================] - 2s 170ms/step - loss: 0.9404 - accuracy: 0.5506 - val_loss: 1.8725 - val_accuracy: 0.4500
# Epoch 67/100
# 12/12 [==============================] - 2s 170ms/step - loss: 1.0055 - accuracy: 0.5056 - val_loss: 2.0131 - val_accuracy: 0.4500
# Epoch 68/100
# 12/12 [==============================] - 2s 170ms/step - loss: 1.2140 - accuracy: 0.4607 - val_loss: 2.2157 - val_accuracy: 0.4500
# Epoch 69/100
# 12/12 [==============================] - 2s 173ms/step - loss: 0.9605 - accuracy: 0.6067 - val_loss: 2.0112 - val_accuracy: 0.4500
# Epoch 70/100
# 12/12 [==============================] - 2s 171ms/step - loss: 0.8548 - accuracy: 0.6292 - val_loss: 1.9765 - val_accuracy: 0.4250
# Epoch 71/100
# 12/12 [==============================] - 2s 171ms/step - loss: 1.1368 - accuracy: 0.4896 - val_loss: 2.0289 - val_accuracy: 0.4500
# Epoch 72/100
# 12/12 [==============================] - 2s 170ms/step - loss: 1.0050 - accuracy: 0.5169 - val_loss: 1.9814 - val_accuracy: 0.4500
# Epoch 73/100
# 12/12 [==============================] - 2s 173ms/step - loss: 1.1227 - accuracy: 0.4607 - val_loss: 1.7663 - val_accuracy: 0.4500
# Epoch 74/100
# 12/12 [==============================] - 2s 172ms/step - loss: 0.7609 - accuracy: 0.5955 - val_loss: 2.1895 - val_accuracy: 0.4500
# Epoch 75/100
# 12/12 [==============================] - 2s 170ms/step - loss: 1.1303 - accuracy: 0.4719 - val_loss: 2.0138 - val_accuracy: 0.4500
# Epoch 76/100
# 12/12 [==============================] - 2s 173ms/step - loss: 1.1085 - accuracy: 0.5506 - val_loss: 1.9462 - val_accuracy: 0.4250
# Epoch 77/100
# 12/12 [==============================] - 2s 172ms/step - loss: 0.8885 - accuracy: 0.6404 - val_loss: 1.9703 - val_accuracy: 0.4500
# Epoch 78/100
# 12/12 [==============================] - 2s 170ms/step - loss: 0.9656 - accuracy: 0.5056 - val_loss: 1.6657 - val_accuracy: 0.4250
# Epoch 79/100
# 12/12 [==============================] - 2s 170ms/step - loss: 0.9884 - accuracy: 0.5618 - val_loss: 1.8269 - val_accuracy: 0.4500
# Epoch 80/100
# 12/12 [==============================] - 2s 171ms/step - loss: 0.9208 - accuracy: 0.5393 - val_loss: 1.9884 - val_accuracy: 0.4250
# Epoch 81/100
# 12/12 [==============================] - 2s 170ms/step - loss: 1.0675 - accuracy: 0.5169 - val_loss: 2.1486 - val_accuracy: 0.4500
# Epoch 82/100
# 12/12 [==============================] - 2s 171ms/step - loss: 1.2646 - accuracy: 0.4896 - val_loss: 1.9776 - val_accuracy: 0.4500
# Epoch 83/100
# 12/12 [==============================] - 2s 169ms/step - loss: 0.9806 - accuracy: 0.5618 - val_loss: 1.8969 - val_accuracy: 0.4500
# Epoch 84/100
# 12/12 [==============================] - 2s 168ms/step - loss: 0.9352 - accuracy: 0.5730 - val_loss: 2.0593 - val_accuracy: 0.4500
# Epoch 85/100
# 12/12 [==============================] - 2s 170ms/step - loss: 0.9066 - accuracy: 0.5056 - val_loss: 2.2921 - val_accuracy: 0.4250
# Epoch 86/100
# 12/12 [==============================] - 2s 170ms/step - loss: 0.9182 - accuracy: 0.6292 - val_loss: 1.9267 - val_accuracy: 0.4500
# Epoch 87/100
# 12/12 [==============================] - 2s 170ms/step - loss: 1.1746 - accuracy: 0.5169 - val_loss: 2.1248 - val_accuracy: 0.4500
# Epoch 88/100
# 12/12 [==============================] - 2s 172ms/step - loss: 0.9205 - accuracy: 0.6180 - val_loss: 1.8311 - val_accuracy: 0.4500
# Epoch 89/100
# 12/12 [==============================] - 2s 174ms/step - loss: 0.9160 - accuracy: 0.6180 - val_loss: 1.7759 - val_accuracy: 0.4500
# Epoch 90/100
# 12/12 [==============================] - 2s 174ms/step - loss: 0.9236 - accuracy: 0.6854 - val_loss: 2.2031 - val_accuracy: 0.4500
# Epoch 91/100
# 12/12 [==============================] - 2s 174ms/step - loss: 1.0632 - accuracy: 0.5393 - val_loss: 1.8194 - val_accuracy: 0.4250
# Epoch 92/100
# 12/12 [==============================] - 2s 170ms/step - loss: 0.9667 - accuracy: 0.6292 - val_loss: 1.9952 - val_accuracy: 0.4000
# Epoch 93/100
# 12/12 [==============================] - 2s 171ms/step - loss: 1.2118 - accuracy: 0.5281 - val_loss: 2.0765 - val_accuracy: 0.4500
# Epoch 94/100
# 12/12 [==============================] - 2s 171ms/step - loss: 1.0950 - accuracy: 0.5056 - val_loss: 2.3041 - val_accuracy: 0.4500
# Epoch 95/100
# 12/12 [==============================] - 2s 171ms/step - loss: 1.1474 - accuracy: 0.4944 - val_loss: 1.6186 - val_accuracy: 0.4500
# Epoch 96/100
# 12/12 [==============================] - 2s 171ms/step - loss: 1.0487 - accuracy: 0.5730 - val_loss: 1.8350 - val_accuracy: 0.4500
# Epoch 97/100
# 12/12 [==============================] - 2s 171ms/step - loss: 0.7855 - accuracy: 0.6180 - val_loss: 1.8615 - val_accuracy: 0.4500
# Epoch 98/100
# 12/12 [==============================] - 2s 169ms/step - loss: 0.9297 - accuracy: 0.5955 - val_loss: 2.2320 - val_accuracy: 0.4250
# Epoch 99/100
# 12/12 [==============================] - 2s 171ms/step - loss: 0.8844 - accuracy: 0.5955 - val_loss: 1.8126 - val_accuracy: 0.4250
# Epoch 100/100
# 12/12 [==============================] - 2s 171ms/step - loss: 0.9431 - accuracy: 0.5618 - val_loss: 1.7369 - val_accuracy: 0.4750

# %%
# Save model weights
model.save_weights(output +'weights.h5')

#model. get_weights()  # for checking weights

# %%
# plot training

from matplotlib import pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

with PdfPages(output +'plot.pdf') as pdf:
    
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    plt.figure(figsize=(8, 8))
    plt.subplot(2, 1, 1)
    plt.plot(acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.ylabel('Accuracy')
    plt.title('Training and Validation Accuracy')

    plt.subplot(2, 1, 2)
    plt.plot(loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.ylabel('Cross Entropy')
    plt.title('Training and Validation Loss')
    plt.xlabel('epoch')
    pdf.savefig();
    plt.show()
    plt.close()

# %%
#predict test_data

def probas_to_classes(y_pred):
    return np.array([1 if p > 0.5 else 0 for p in y_pred])

#create Image generator
datagen_test = ImageDataGenerator(
        rescale=1./255)  # set values to 0-1

#Note. not sure if these have to be reshuffled during iterations
#create generator for training data
test_generator = datagen_test.flow_from_dataframe(
        dataframe=df_test,
        x_col="filename",
        y_col="class",
        target_size=(IMAGE_SIZE, IMAGE_SIZE),
        shuffle = False,
        color_mode = 'grayscale' if CHANNELS == 1 else 'rgb' )

# run testdata
prediction = model.predict(test_generator)
pred_classes = probas_to_classes(prediction)

print(test_generator.class_indices)

for i in range(0,len(prediction)):
    pred_class = list(test_generator.class_indices.keys())[list(test_generator.class_indices.values()).index(pred_classes[i])]
    print(test_filenames[i] + ' - ' + test_labels[i] + ' - ' + str(prediction[i])+ ' - pred: ' + pred_class)
# Out:
# Found 16 validated image filenames belonging to 2 classes.
# {'CB': 0, 'UT': 1}
# D:\work\48h_output\max\ch3\015.png - CB - [0.9706472] - pred: UT
# D:\work\48h_output\max\ch3\162.png - UT - [0.92173254] - pred: UT
# D:\work\48h_output\max\ch3\220.png - UT - [0.9736472] - pred: UT
# D:\work\48h_output\max\ch3\173.png - UT - [0.95838654] - pred: UT
# D:\work\48h_output\max\ch3\177.png - UT - [0.9272237] - pred: UT
# D:\work\48h_output\max\ch3\065.png - CB - [0.9514954] - pred: UT
# D:\work\48h_output\max\ch3\018.png - CB - [0.99706864] - pred: UT
# D:\work\48h_output\max\ch3\045.png - CB - [0.9741558] - pred: UT
# D:\work\48h_output\max\ch3\036.png - CB - [0.9653702] - pred: UT
# D:\work\48h_output\max\ch3\055.png - CB - [0.96642697] - pred: UT
# D:\work\48h_output\max\ch3\153.png - UT - [0.9865571] - pred: UT
# D:\work\48h_output\max\ch3\210.png - UT - [0.9667902] - pred: UT
# D:\work\48h_output\max\ch3\019.png - CB - [0.96081406] - pred: UT
# D:\work\48h_output\max\ch3\215.png - UT - [0.9904015] - pred: UT
# D:\work\48h_output\max\ch3\154.png - UT - [0.99203] - pred: UT
# D:\work\48h_output\max\ch3\161.png - UT - [0.7506875] - pred: UT
